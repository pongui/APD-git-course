# %%
 # EXO 1

a=int(input("veuillez saisir un nombre:"))
b=int(input("veuillez saisir un nombre:"))
c=int(input("veuillez saisir un nombre:"))a
if a > b :
    if a > c :
        max = a
    else:
        max  = c
else:
            if b > c :
                max = b
            else: 
        
                    max = c
        
print("le maximun est ", max) 

#  EXO2

j=input("entrer la lettre que vous vouler:")
if j=="a" or j=="i" or j=="u" or j=="o"   or j=="e":
    print(j,"est une voyelle")
else:
    print(j,"est un consonne")

# EXO 3

j=int(input("veuillez  saisir un  nombre :"))
if j== 1 :
    print("lundi")
if j== 2 : 
    print("mardi")
if j ==3 :
    print("mercredi")
if j== 4 :
    print("jeudi")
if j==5 :
    print("vendredi")
if j==6 :
    print("samedi")
if j== 7:
    print("dimanche")
else:
    print("veuillez entrer le bon numero")

#  EXO 4

nput("mon produit :")
pv=int(input("prix de vente" ))
pf=int(input("prix de fabrication"))
if pf > pv:
    print("il y'a perte")
else:
    print("il y'a profit")

# EXO  5

bx=int(input("entrer l' annee choisi"))
if bx%4==0  and bx%100!=0:
    print(bx,"l'annee est bisextille")
elif bx%400==0 and bx%100!=0:
    print(bx,"l' annee est bisextille")
else:
    print(bx,"l'annee n'est pas bisextille")
    

# EXO 6

for i in range (4):
    print(i*"*")


# EXO 7

m=input('veuillez le mot tester')
p=len(m)
mv=0
for i in range (0,p):
     if m  [i]   in  ["a","u","i","e","o"]:
            mv=mv + 1
            
print(mv,"est le nombre de voyelle",m)        

#  EXO 8

c=1
for i in range (18,0,-1):
    if i%3==0:
        c=i
        print(c)

#  EXO 9

a=int(input("entre la note maximal:"))
b=int(input("entre la note minimal:"))
if (a<b):
    print(a,'affiche la moyenne maximal')
else:
    print(b,'affiche la moyenne minimal')
    
      

# EXO 10

input("tu es gardient")
input("tu aime ton boulot")
input("tu as des enfants")

# EXO 11

nombre_total_essai=5
borne_sup=100
borne_inf=1
n=2
print("petit jeu permettant de deviner un nombre entre borne_inf",borne_inf,"borne_sup",borne_sup)

for nbr_choisi in range(1,n):
    nombre_essai=1
    
    while true:
        print("entrer un entier compris entre:",borne_inf,"et",borne_sup)
        print("incorrecte",nombre_essai)
        nombre_devine=int(input())
        if nombre_devine==nbr_choisi:
            print("bravo! vous avez trouve le nombre d'essai",nombre_essai)
             break
        elif nombre_devine==nbr_choisi:
            print("trés petit! choisir un autre plus grand ")
        else:
            print("tres grand! choisir un autre plus petit")
            
            if nombre_essai==nombre_total_essais:
                print("game over!!! le nombre cherche était",nbr_choisi)
                
                break

# EXO 12

a=eval(input("entrez un nombre:"))
b=eval(input("entrez un nombre:"))

r=a%b
         
print("le pgcd de:",a,"et",b,"est:",r)





# EXO 13

for i in range(1,6):
    for i in range(10):
        print(i,end="")
    print()    
         

# EXO 14

a=int(input("veuillez saisir un nombre :"))
b=int(input("veuillez saisir un nombre:"))
c=int(input("veuillez saisir un nombre:"))
d=int(input("veuillez saisir un nombre:"))
som=0
for i in range (0,1):
    som=(a+b+c+d)
    print("la somme est", som)

# EXO 15

som=0
for i in range(1,10):
    ca=i*i
    som=som +ca
    print(i,"son carré est",ca)
print(som,"la somme des carres des nombres conpris entre 1 et 10")    

 # EXO 16

i=1
while i < 150:
    i=i+1
    if i%7==0:
        print(i)

# EXO 17

for i in range(50):
    if i**2 >1000:
        print(i)
        break

# EXO 18

nbr=int(input('entre un nombre'))
s=0
tmp=nbr

while tmp>0:
        d=tmp % 10
        s+=d**3
        tmp//=10
        if nbr==s:
            print(nbr,'est un nombre armstrong')
        else:
            print(nbr,"n'est pas un nombre armstrong")

# EXO 19

n=int(input("veuillez entrer un nombre"))
if(n==0):
    print(n,'est nul')
elif(n%2==0):
    print(n,"est parfait")
else:
    print(n,"n'est pas parfait")
if(n < 0) :
    print(n ,"est inferieur")
elif (n>0):
    print(n,"est superieur")

# EXO 20

a=int(input("donner le 1er nombre:"))
b=int(input("donner le 2er nombre:"))
if a>=b:
    pg=a
else:
    pg=b
    i=a*b
while i>=pg:
    if i%a==0 and i%b==0:
        i=i-1
print("le ppcm de ",a,"et",b,"est:",pg)

# %% [markdown]
# # Exo modifié

# %%
for i in range(1,10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
